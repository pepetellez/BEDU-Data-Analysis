# %% [markdown]
# <a href="https://colab.research.google.com/github/pepetellez/BEDU-Data-Analysis/blob/main/Procesamiento-de-Datos-con-Python/8_Bases_de_datos_merge_y_agrupaciones/s8_r4_las_mejores_50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Reto 4: Las mejores 50
#
# ### 1. Objetivos:
#     - Practicar las siguientes herramientas:
#         - Lectura de .csv
#         - Agrupaciones y reducciones
#         - Reordenamiento
#         - Unión de `DataFrames` usando `merge`
#
# ---
#
# ### 2. Desarrollo:

# %% [markdown]
# #### a) Las 50 películas con mejor rating
#
# Vamos a hacer una visualización muy sencilla de las 50 películas que tienen mejor rating en nuestro dataset. Tu Reto consiste en seguir los siguientes pasos:
#
# 1. Lee los archivos `movies` y `ratings`.
# 2. Agrupa `ratings` por id de película y computa el promedio de `rating` para cada película
# 3. Crea un nuevo `DataFrame` que sólo contenga las 50 películas con mejor promedio de ratings
# 4. Agrega al `DataFrame` anterior los nombres de las películas usando la tabla `movies`.
# 5. Al final tendrás un `DataFrame` con los nombres de las 50 películas con mejor rating ('title') y el promedio de sus ratings ('rating'). Asigna este resultado a la variable `las_mejores_50`.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

#Lee los archivos movies y ratings.
movies = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/Datasets/MovieLens/movies-separated_by_money-raw.csv', sep="$", index_col=0)
ratings = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/Datasets/MovieLens/ratings-raw.csv', index_col=0)

#Agrupa ratings por id de película y computa el promedio de rating para cada película
means_of_ratings = ratings.groupby('movie_id')['rating'].mean()

#Crea un nuevo DataFrame que sólo contenga las 50 películas con mejor promedio de ratings
means_of_ratings_top_50 = means_of_ratings.sort_values(ascending=False).head(50)

#Agrega al DataFrame anterior los nombres de las películas usando la tabla movies.
las_mejores_50 = pd.merge(means_of_ratings_top_50, movies, left_index=True, right_on='movie_id')
las_mejores_50
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#             rating  ...                           genres
# movie_id            ...
# 3382      5.000000  ...                            Drama
# 3172      5.000000  ...                        Adventure
# 3607      5.000000  ...             Comedy|Drama|Western
# 3656      5.000000  ...                            Crime
# 3280      5.000000  ...                           Horror
# 787       5.000000  ...                      Documentary
# 1830      5.000000  ...                           Comedy
# 989       5.000000  ...                            Drama
# 3881      5.000000  ...                      Documentary
# 3233      5.000000  ...                           Comedy
# 3245      4.800000  ...                            Drama
# 53        4.750000  ...                            Drama
# 2503      4.666667  ...                            Drama
# 2905      4.608696  ...                 Action|Adventure
# 2019      4.560510  ...                     Action|Drama
# 318       4.554558  ...                            Drama
# 858       4.524966  ...               Action|Crime|Drama
# 745       4.520548  ...        Animation|Comedy|Thriller
# 50        4.517106  ...                   Crime|Thriller
# 527       4.510417  ...                        Drama|War
# 1148      4.507937  ...                 Animation|Comedy
# 2309      4.500000  ...                            Drama
# 3888      4.500000  ...                    Drama|Romance
# 439       4.500000  ...                            Drama
# 1795      4.500000  ...                            Drama
# 2480      4.500000  ...                            Drama
# 3517      4.500000  ...                      Crime|Drama
# 578       4.500000  ...                    Drama|Mystery
# 557       4.500000  ...                            Drama
# 922       4.491489  ...                        Film-Noir
# 1198      4.477725  ...                 Action|Adventure
# 904       4.476190  ...                 Mystery|Thriller
# 1178      4.473913  ...                        Drama|War
# 260       4.453694  ...  Action|Adventure|Fantasy|Sci-Fi
# 1212      4.452083  ...                 Mystery|Thriller
# 750       4.449890  ...                       Sci-Fi|War
# 3338      4.444444  ...                      Documentary
# 720       4.426941  ...                        Animation
# 1207      4.425647  ...                            Drama
# 3435      4.415608  ...                  Crime|Film-Noir
# 912       4.412822  ...                Drama|Romance|War
# 670       4.410714  ...                            Drama
# 2762      4.406263  ...                         Thriller
# 3030      4.404651  ...             Comedy|Drama|Western
# 668       4.404255  ...                            Drama
# 1204      4.401925  ...                    Adventure|War
# 2930      4.400000  ...                      Documentary
# 913       4.395973  ...                Film-Noir|Mystery
# 1193      4.390725  ...                            Drama
# 923       4.388889  ...                            Drama
#
# [50 rows x 3 columns]

# %% [markdown]
# Pídele a tu experta la función de verificación `plotting_best_50` (encontrada en el archivo `helpers.py` de la carpeta donde se encuentra este Reto), pégala debajo y corre la celda para verificar tu resultado:

# %%
# Pega aquí la función de verificación

def plotting_best_50(las_mejores_50):
    import seaborn as sns
    import matplotlib.pyplot as plt
    
    fig, ax = plt.subplots(figsize=(10, 20))
    ax.set_title('Top 50 Movies with Best Ratings')
    splot = sns.barplot(las_mejores_50['rating'], las_mejores_50['title'], ax=ax)
    ax.set(xlabel='Rating', ylabel='Movie Title')

plotting_best_50(las_mejores_50)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# <details><summary>Solución</summary>
#
# ```python
# movies = pd.read_csv('../../Datasets/MovieLens/movies-separated_by_money-raw.csv', sep='$', index_col=0)
# ratings = pd.read_csv('../../Datasets/MovieLens/ratings-raw.csv', index_col=0)
# means_of_ratings = ratings.groupby('movie_id')['rating'].mean()
# means_of_ratings_top_50 = means_of_ratings.sort_values(ascending=False).head(50)
# las_mejores_50 = pd.merge(means_of_ratings_top_50, movies, left_index=True, right_on='movie_id')
# ```
#
# </details>
